# %% [markdown]
# **Importar Dataset desde el Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
np.seterr(divide='ignore', invalid='ignore')

def cromaticCoords(img):
      R = img[:,:,0]
      G = img[:,:,1]
      B = img[:,:,2]
    
      new_img = np.zeros(np.shape(img))
      r  = R/(R+G+B)
      g  = G/(R+G+B)
      b  = B/(R+G+B)
    
      new_img[:,:,0] = r
      new_img[:,:,1] = g
      new_img[:,:,2] = b
        
      return new_img

# %% [markdown]
# en este segmento se crea una lista con los indices de los tipos de celulas blancas presentes en el dataset, para mayor entendimiento a la hora de la clasificación.

# %%
import pandas as pd

labels = pd.read_csv("/content/drive/Shareddrives/Deteccion de bacterias/Globulos/dataset2-master/dataset2-master/labels.csv")
labels = labels.dropna(subset = ["Category"])

arrayNeutrophil = labels[labels['Category'] == 'NEUTROPHIL'].index.to_numpy()
arrayMonocyte = labels[labels['Category'] == 'MONOCYTE'].index.to_numpy()
arraysLymphocyte = labels[labels['Category'] == 'LYMPHOCYTE'].index.to_numpy()
arraysEosinophil = labels[labels['Category'] == 'EOSINOPHIL'].index.to_numpy()

print(arrayNeutrophil)
print(arrayMonocyte)
print(arraysLymphocyte)
print(arraysEosinophil)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-56ada2e6c726> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 labels = pd.read_csv("/content/drive/Shareddrives/Deteccion de bacterias/Globulos/dataset2-master/dataset2-master/labels.csv")
#       4 labels = labels.dropna(subset = ["Category"])
#       5
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import cv2
import matplotlib.pyplot as plt

test_img = cv2.cvtColor(cv2.imread("/content/drive/Shareddrives/Deteccion de bacterias/Globulos/dataset2-master/dataset2-master/images/TEST_SIMPLE/EOSINOPHIL/_0_5239.jpeg"),cv2.COLOR_BGR2RGB)

plt.imshow(test_img)
